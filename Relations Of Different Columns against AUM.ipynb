# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('master_conservation_projects_database.csv',encoding='mac_roman')

# %%
print('Shape of our data {}'.format(data.shape))
# Out:
# Shape of our data (84, 22)

# %%
data.describe(include='all')
# Out:
#                       Organization   HQ  Year Established  \
# count                           84   84         84.000000
# unique                          18   11               NaN
# top     Ecotrust Forest Management  USA               NaN
# freq                            15   37               NaN
# mean                           NaN  NaN       2006.583333
# std                            NaN  NaN          9.799445
# min                            NaN  NaN       1982.000000
# 25%                            NaN  NaN       2004.000000
# 50%                            NaN  NaN       2006.000000
# 75%                            NaN  NaN       2015.000000
# max                            NaN  NaN       2017.000000
#
#        Type of Organization           Size (AUM)           AUM Project Name  \
# count                    84                   84     84.000000           84
# unique                   13                   19           NaN           73
# top                    TIMO  USD 190 million AUM           NaN    MTO Group
# freq                     33                   15           NaN            3
# mean                    NaN                  NaN    893.084524          NaN
# std                     NaN                  NaN   1430.100248          NaN
# min                     NaN                  NaN     54.000000          NaN
# 25%                     NaN                  NaN    190.000000          NaN
# 50%                     NaN                  NaN    300.000000          NaN
# 75%                     NaN                  NaN    582.000000          NaN
# max                     NaN                  NaN  10000.000000          NaN
#
#        Financial Asset Class Natural Asset Class Returns Profile (Target IRR)  \
# count                     84                  84                           84
# unique                    11                   6                           16
# top      Equity, Grant, Loan              Forest                        5.90%
# freq                      23                  38                           15
# mean                     NaN                 NaN                          NaN
# std                      NaN                 NaN                          NaN
# min                      NaN                 NaN                          NaN
# 25%                      NaN                 NaN                          NaN
# 50%                      NaN                 NaN                          NaN
# 75%                      NaN                 NaN                          NaN
# max                      NaN                 NaN                          NaN
#
#         ...       Tree Species   Project City Project State Project Country  \
# count   ...                 65             42            66              84
# unique  ...                 36             31            35              29
# top     ...  Eucalyptus & Pine  Callam County            CA             USA
# freq    ...                 10              3            15              36
# mean    ...                NaN            NaN           NaN             NaN
# std     ...                NaN            NaN           NaN             NaN
# min     ...                NaN            NaN           NaN             NaN
# 25%     ...                NaN            NaN           NaN             NaN
# 50%     ...                NaN            NaN           NaN             NaN
# 75%     ...                NaN            NaN           NaN             NaN
# max     ...                NaN            NaN           NaN             NaN
#
#          Latitude   Longitude  \
# count   84.000000   84.000000
# unique        NaN         NaN
# top           NaN         NaN
# freq          NaN         NaN
# mean    13.821929  -49.285689
# std     27.556200   77.333738
# min    -36.896529 -124.517829
# 25%     -6.618445 -121.712307
# 50%     14.212073  -76.997422
# 75%     40.648396   21.338015
# max     48.246431  174.528273
#
#                                       Project Description  \
# count                                                  84
# unique                                                 74
# top     MTO operates pine and eucalyptus plantations, ...
# freq                                                    3
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                          Project Website          Contact Approved
# count                                 84               83       84
# unique                                40               19        1
# top     https://efmi.com/our-properties/  invest@efmi.com     True
# freq                                  15               15       84
# mean                                 NaN              NaN      NaN
# std                                  NaN              NaN      NaN
# min                                  NaN              NaN      NaN
# 25%                                  NaN              NaN      NaN
# 50%                                  NaN              NaN      NaN
# 75%                                  NaN              NaN      NaN
# max                                  NaN              NaN      NaN
#
# [11 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Organization                  84 non-null     object
#  1   HQ                            84 non-null     object
#  2   Year Established              84 non-null     int64
#  3   Type of Organization          84 non-null     object
#  4   Size (AUM)                    84 non-null     object
#  5   AUM                           84 non-null     float64
#  6   Project Name                  84 non-null     object
#  7   Financial Asset Class         84 non-null     object
#  8   Natural Asset Class           84 non-null     object
#  9   Returns Profile (Target IRR)  84 non-null     object
#  10  Sustainability Profile        84 non-null     object
#  11  Project Size (hectares)       74 non-null     object
#  12  Tree Species                  65 non-null     object
#  13  Project City                  42 non-null     object
#  14  Project State                 66 non-null     object
#  15  Project Country               84 non-null     object
#  16  Latitude                      84 non-null     float64
#  17  Longitude                     84 non-null     float64
#  18  Project Description           84 non-null     object
#  19  Project Website               84 non-null     object
#  20  Contact                       83 non-null     object
#  21  Approved                      84 non-null     bool
# dtypes: bool(1), float64(3), int64(1), object(17)
# memory usage: 14.0+ KB

# %%
sns.histplot(data.AUM, kde=True)
plt.show()

# %%
# data[-15:].plot(x='Year Established', y=['Project Size (hectares)', 'AUM'], figsize=(10,5), grid=True)
data.plot.scatter(x='AUM', y = 'Year Established', figsize=(10,5), grid=True)
# Out:
# <AxesSubplot:xlabel='AUM', ylabel='Year Established'>

# %%
data.AUM.describe()
# Out:
# count       84.000000
# mean       893.084524
# std       1430.100248
# min         54.000000
# 25%        190.000000
# 50%        300.000000
# 75%        582.000000
# max      10000.000000
# Name: AUM, dtype: float64

# %%
for x in range(81, 101 , 1):
    print("{}% of AUM are less than equal to {}".format(x, data.AUM.quantile(x/100)))
iqr = data.AUM.quantile(0.75) - data.AUM.quantile(0.25) # To get the inter quantile range. (75% - 25%)
print('IQR {}'.format(iqr))
# Out:
# 81% of AUM are less than equal to 1414.0000000000073
# 82% of AUM are less than equal to 2800.0
# 83% of AUM are less than equal to 2800.0
# 84% of AUM are less than equal to 2800.0
# 85% of AUM are less than equal to 2800.0
# 86% of AUM are less than equal to 2800.0
# 87% of AUM are less than equal to 2800.0
# 88% of AUM are less than equal to 2800.0
# 89% of AUM are less than equal to 2800.0
# 90% of AUM are less than equal to 2940.000000000001
# 91% of AUM are less than equal to 3000.0
# 92% of AUM are less than equal to 3000.0
# 93% of AUM are less than equal to 3000.0
# 94% of AUM are less than equal to 3000.0
# 95% of AUM are less than equal to 3000.0
# 96% of AUM are less than equal to 3000.0
# 97% of AUM are less than equal to 3000.0
# 98% of AUM are less than equal to 3000.0
# 99% of AUM are less than equal to 4190.000000000012
# 100% of AUM are less than equal to 10000.0
# IQR 392.0

# %%
sns.set(style="darkgrid")
sns.relplot(x="AUM", y="HQ", data=data);

# %%
sns.relplot(x="AUM", y="HQ", hue="Organization",height=12,alpha=.9, data=data)

# %%
sns.relplot(x="AUM", y="HQ", hue="Type of Organization",height=12,alpha=.9, data=data)

# %%
sns.relplot(x="AUM", y="Financial Asset Class", hue="Organization",height=12,alpha=.9, data=data)

# %%
data['Project Size (hectares)'].fillna('10,000', inplace=True)

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.1.0-py3-none-any.whl (112 kB)
# Collecting geographiclib<2,>=1.49
#   Downloading geographiclib-1.50-py3-none-any.whl (38 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-2.1.0

# %%
# import module
from geopy.geocoders import Nominatim
  
# initialize Nominatim API
geolocator = Nominatim(user_agent="geoapiExercises")
  
# Latitude & Longitude input
Latitude = "2.269494556"
Longitude = "-72.75852614"
  
location = geolocator.reverse(Latitude+","+Longitude)
  
address = location.raw['address']
  
# traverse the data
city = address.get('city', '')
state = address.get('state', '')
country = address.get('country', '')
code = address.get('country_code')
zipcode = address.get('postcode')
print('City : ', city)
print('State : ', state)
print('Country : ', country)
print('Zip Code : ', zipcode)
# Out:
# City :
# State :  Guaviare
# Country :  Colombia
# Zip Code :  None

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'American Samoa': 'AS',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'District of Columbia': 'DC',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Guam': 'GU',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Northern Mariana Islands':'MP',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Puerto Rico': 'PR',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virgin Islands': 'VI',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %%
def set_state(x):
    
    if str(x['Project State']) == 'nan':
        
        Latitude = str(x['Latitude'])
        Longitude = str(x['Longitude'])

        location = geolocator.reverse(Latitude+","+Longitude)

        if "state" in location.raw['address'].keys():
            state = location.raw['address']['state']
            
        elif "region" in location.raw['address'].keys():
            state = location.raw['address']['region']
        
        elif "territory" in location.raw['address'].keys():
            state = location.raw['address']['territory']
        
        else:    
            return np.nan

        # just the american ones have the abbreviation
        if state in us_state_abbrev:
            return us_state_abbrev[state]
        else:
            return state
    
    else:
        return x['Project State']

# %%
def set_city(x):
    
    if str(x['Project City']).lower() == 'nan':
        
        Latitude = str(x['Latitude'])
        Longitude = str(x['Longitude'])

        location = geolocator.reverse(Latitude+","+Longitude)

        # there are several combinations
        
        if "town" in location.raw['address'].keys():
            return location.raw['address']['town']
        
        elif "city" in location.raw['address'].keys():
            return location.raw['address']['city']
        
        elif "county" in location.raw['address'].keys():
            return location.raw['address']['county']
        
        elif "village" in location.raw['address'].keys():
            return location.raw['address']['village']
        
        elif "suburb" in location.raw['address'].keys():
            return location.raw['address']['suburb']
        
        elif "state_district" in location.raw['address'].keys():
            return location.raw['address']['state_district']
        
        else:
            return np.nan
    
    else:
        return x['Project City']

# %%
df_cleaned = data.copy()
df_cleaned['Project State'] = data.apply(lambda x : set_state(x), axis=1)
df_cleaned['Project City'] = data.apply(lambda x : set_city(x), axis=1)

# %%
df_cleaned.isnull().sum()[['Project City','Project State']]
# Out:
# Project City     3
# Project State    0
# dtype: int64

# %%
df_cleaned.at[21,'Project City'] = "Samraong"
df_cleaned.at[34,'Project City'] = "Bengalon"
df_cleaned.at[83,'Project City'] = "Luwanda"

# %%
df_cleaned.isnull().sum()[['Project City','Project State']]
# Out:
# Project City     0
# Project State    0
# dtype: int64

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 22 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Organization                  84 non-null     object
#  1   HQ                            84 non-null     object
#  2   Year Established              84 non-null     int64
#  3   Type of Organization          84 non-null     object
#  4   Size (AUM)                    84 non-null     object
#  5   AUM                           84 non-null     float64
#  6   Project Name                  84 non-null     object
#  7   Financial Asset Class         84 non-null     object
#  8   Natural Asset Class           84 non-null     object
#  9   Returns Profile (Target IRR)  84 non-null     object
#  10  Sustainability Profile        84 non-null     object
#  11  Project Size (hectares)       84 non-null     object
#  12  Tree Species                  65 non-null     object
#  13  Project City                  84 non-null     object
#  14  Project State                 84 non-null     object
#  15  Project Country               84 non-null     object
#  16  Latitude                      84 non-null     float64
#  17  Longitude                     84 non-null     float64
#  18  Project Description           84 non-null     object
#  19  Project Website               84 non-null     object
#  20  Contact                       83 non-null     object
#  21  Approved                      84 non-null     bool
# dtypes: bool(1), float64(3), int64(1), object(17)
# memory usage: 14.0+ KB

# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: six in c:\anaconda\lib\site-packages (from plotly) (1.15.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py): started
#   Building wheel for retrying (setup.py): finished with status 'done'
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11434 sha256=7fa914456fb9e42a89b8053b6f2a5fcff2164ab2200c626cca1496f58a161e41
#   Stored in directory: c:\users\nisarg mehta\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.14.3 retrying-1.3.3

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly
import plotly.graph_objs as go

init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fig = px.box(data, y='AUM')
fig.show()
# Out:
# <div>                            <div id="581bbc35-5ec5-4807-a75c-4ad535ec4e3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("581bbc35-5ec5-4807-a75c-4ad535ec4e3e")) {                    Plotly.newPlot(                        "581bbc35-5ec5-4807-a75c-4ad535ec4e3e",                        [{"alignmentgroup": "True", "hovertemplate": "AUM=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x0": " ", "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0], "y0": " ", "yaxis": "y"}],                        {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewid ...

# %%
trace = go.Bar(
    # x=data['Organization'].unique(),
    x=data['Organization'],
    y=data['AUM']
#     name='Number of games released'
)

# Define the data array
data1 = [trace]

# Set the title
layout = {'title': 'Comparision'}

# Create a Figure and plot it
fig = go.Figure(data=data1, layout=layout)
iplot(fig, show_link=False)
# Out:
# <div>                            <div id="cadbc154-6f20-4146-b2f8-d4c89e47e4b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cadbc154-6f20-4146-b2f8-d4c89e47e4b1")) {                    Plotly.newPlot(                        "cadbc154-6f20-4146-b2f8-d4c89e47e4b1",                        [{"type": "bar", "x": ["Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Ecosystem Investment Partners (EIP)", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "Lyme Forest Fund", "The Conservation Fund", "New Forests", "New Forests", "New Forests", "New Forests", "New Forests", "New Forests", "New Forests", "Tropical Landscapes Finance Facility", "Tropical Landscapes Finance Facility", "&Green Fund", "The Forest Company", "The Forest Company", "The Forest Company", "The Forest Company", "The Forest Company", "The Forest Company", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Global Forest Partners LP", "Green Climate Fund", "Eco.business Fund", "Eco.business Fund", "Eco.business Fund", "Mirova Natural Capital (prev. Althelia Climate Fund)", "Mirova Natural Capital (prev. Althelia Climate Fund)", "Arbaro Fund", "Arbaro Fund", "Arbaro Fund", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Criterion Africa Partners", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "Ecotrust Forest Management", "NatureVest", "World Bank Climate Pilot Aucation Facility (PAF)", "World Bank Climate Pilot Aucation Facility (PAF)", "Conservation Capital", "Conservation Capital", "Conservation Capital", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100", "AFR100"], "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "tick ...

# %%
# Create a line (trace) for the number of games released
# trace0 = go.Bar(
#     x=data['Organization'],
#     y=data['AUM']
# )
trace1 = go.Bar(
    x=data['Year Established'],
    y=data['AUM'],
)

# Define the data array
data1 = [trace1]

# Set the title
layout = {'title': 'Comparision'}

# Create a Figure and plot it
fig = go.Figure(data=data1, layout=layout)
iplot(fig, show_link=True)
# Out:
# <div>                            <div id="b5daea3b-8c88-44ee-8a51-895dbec33ce9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("b5daea3b-8c88-44ee-8a51-895dbec33ce9")) {                    Plotly.newPlot(                        "b5daea3b-8c88-44ee-8a51-895dbec33ce9",                        [{"type": "bar", "x": [2006, 2006, 2007, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 2006, 1985, 2005, 2005, 2005, 2005, 2005, 2005, 2005, 2016, 2016, 2017, 2007, 2007, 2007, 2007, 2007, 2007, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 1982, 2010, 2014, 2014, 2014, 2012, 2012, 2016, 2016, 2016, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2017, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004, 2014, 2015, 2015, 2004, 2004, 2004, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015], "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.111 ...

# %%
fig = px.pie(data, values='AUM', names='Type of Organization', title='Type of Organization vs AUM')
fig.show()
# Out:
# <div>                            <div id="0d7e93c0-ba8a-47ed-9902-5cf7b7e222f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d7e93c0-ba8a-47ed-9902-5cf7b7e222f2")) {                    Plotly.newPlot(                        "0d7e93c0-ba8a-47ed-9902-5cf7b7e222f2",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Type of Organization=%{label}<br>AUM=%{value}<extra></extra>", "labels": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Nonprofit", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Private Sector Financing", "Private Sector Financing", "Investment Fund", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Private Equity Fund", "Impact Investment Fund", "Impact Investment Fund", "Impact Investment Fund", "Investors/ Asset Managers", "Investors/ Asset Managers", "Private Equity Fund", "Private Equity Fund", "Private Equity Fund", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "In-house Impact Investment Team at The Nature Conservancy", "DFI", "DFI", "Impact Driven Company", "Impact Driven Company", "Impact Driven Company", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "con ...

# %%
fig = px.box(data, x='Type of Organization', y='AUM')
fig.show()
# Out:
# <div>                            <div id="4ebf9def-19db-4501-af21-b9299412d97f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4ebf9def-19db-4501-af21-b9299412d97f")) {                    Plotly.newPlot(                        "4ebf9def-19db-4501-af21-b9299412d97f",                        [{"alignmentgroup": "True", "hovertemplate": "Type of Organization=%{x}<br>AUM=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Nonprofit", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Private Sector Financing", "Private Sector Financing", "Investment Fund", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "TIMO", "Private Equity Fund", "Impact Investment Fund", "Impact Investment Fund", "Impact Investment Fund", "Investors/ Asset Managers", "Investors/ Asset Managers", "Private Equity Fund", "Private Equity Fund", "Private Equity Fund", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Private Equity", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "Asset Investment Manager", "In-house Impact Investment Team at The Nature Conservancy", "DFI", "DFI", "Impact Driven Company", "Impact Driven Company", "Impact Driven Company", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund", "Public/Private Equity Fund"], "x0": " ", "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0], "y0": " ", "yaxis": "y"}],                        {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, ...

# %%
fig = px.histogram(data, x="Financial Asset Class", y="AUM", marginal="rug",color ="Organization")
fig.show()
# Out:
# <div>                            <div id="7dfffa7e-ba61-4e96-8238-809990c18443" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7dfffa7e-ba61-4e96-8238-809990c18443")) {                    Plotly.newPlot(                        "7dfffa7e-ba61-4e96-8238-809990c18443",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=Ecosystem Investment Partners (EIP)<br>Financial Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Ecosystem Investment Partners (EIP)", "marker": {"color": "#636efa"}, "name": "Ecosystem Investment Partners (EIP)", "offsetgroup": "Ecosystem Investment Partners (EIP)", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Bonds", "Bonds", "Bonds"], "xaxis": "x", "y": [885.0, 885.0, 885.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=Ecosystem Investment Partners (EIP)<br>Financial Asset Class=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Ecosystem Investment Partners (EIP)", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "Ecosystem Investment Partners (EIP)", "offsetgroup": "Ecosystem Investment Partners (EIP)", "showlegend": false, "type": "box", "x": ["Bonds", "Bonds", "Bonds"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=Lyme Forest Fund<br>Financial Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Lyme Forest Fund", "marker": {"color": "#EF553B"}, "name": "Lyme Forest Fund", "offsetgroup": "Lyme Forest Fund", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Bonds", "Bonds", "NMTC ", "NMTC ", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds"], "xaxis": "x", "y": [300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=Lyme Forest Fund<br>Financial Asset Class=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Lyme Forest Fund", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Lyme Forest Fund", "offsetgroup": "Lyme Forest Fund", "showlegend": false, "type": "box", "x": ["Bonds", "Bonds", "NMTC ", "NMTC ", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=The Conservation Fund<br>Financial Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "The Conservation Fund", "marker": {"color": "#00cc96"}, "name": "The Conservation Fund", "offsetgroup": "The Conservation Fund", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Bonds"], "xaxis": "x", "y": [150.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=The Conservation Fund<br>Financial Asset Class=%{x}<extra></extra>", "jitter": 0, "legendgroup": "The Conservation Fund", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96", "symbol": "line-ns-open"}, "name": "The Conservation Fund", "offsetgroup": "The Conservation Fund", "showlegend": false, "type": "box", "x": ["Bonds"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=New Forests<br>Financial Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "New Forests", "marker": {"color": "#ab63fa"}, "name": "New Forests", "offsetgro ...

# %%
fig = px.histogram(data, x="Financial Asset Class", y="AUM", marginal="box",color ="Type of Organization")
fig.show()
# Out:
# <div>                            <div id="aeec24a9-e66a-46a5-ae2f-1772401f5cf3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aeec24a9-e66a-46a5-ae2f-1772401f5cf3")) {                    Plotly.newPlot(                        "aeec24a9-e66a-46a5-ae2f-1772401f5cf3",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=TIMO<br>Financial Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "TIMO", "marker": {"color": "#636efa"}, "name": "TIMO", "offsetgroup": "TIMO", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "NMTC ", "NMTC ", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment"], "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Type of Organization=TIMO<br>Financial Asset Class=%{x}<extra></extra>", "legendgroup": "TIMO", "marker": {"color": "#636efa"}, "name": "TIMO", "notched": true, "offsetgroup": "TIMO", "showlegend": false, "type": "box", "x": ["Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "NMTC ", "NMTC ", "Bonds", "Bonds", "Bonds", "Bonds", "Bonds", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Commodities", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment", "Capital Commitment"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Nonprofit<br>Financial Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Nonprofit", "marker": {"color": "#EF553B"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Bonds"], "xaxis": "x", "y": [150.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Type of Organization=Nonprofit<br>Financial Asset Class=%{x}<extra></extra>", "legendgroup": "Nonprofit", "marker": {"color": "#EF553B"}, "name": "Nonprofit", "notched": true, "offsetgroup": "Nonprofit", "showlegend": false, "type": "box", "x": ["Bonds"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Private Sector Financing<br>Financial Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Private Sector Financing", "marker": {"color": "#00cc96"}, "name": "Private Sector Financing", "offsetgroup": "Private Sector Financing", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Notes", "Commodities"], "xaxis": "x", "y": [1000.0, 1000.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "Type of Organization=Private Sector Financing<br>Financial Asset Class=%{x}<extra></extra>", "legendgroup": "Private Sector Financing", "marker": {"color": "#00cc96"}, "name": "Private Sector Financing", "notched": true, "offsetgrou ...

# %%
fig = px.histogram(data, x="Returns Profile (Target IRR)", y="AUM", marginal="rug",color ="Type of Organization")
fig.show()
# Out:
# <div>                            <div id="2e017b31-f7f6-4a09-8b86-014b6b76c74d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2e017b31-f7f6-4a09-8b86-014b6b76c74d")) {                    Plotly.newPlot(                        "2e017b31-f7f6-4a09-8b86-014b6b76c74d",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=TIMO<br>Returns Profile (Target IRR)=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "TIMO", "marker": {"color": "#636efa"}, "name": "TIMO", "offsetgroup": "TIMO", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%"], "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=TIMO<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "TIMO", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "TIMO", "offsetgroup": "TIMO", "showlegend": false, "type": "box", "x": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Nonprofit<br>Returns Profile (Target IRR)=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Nonprofit", "marker": {"color": "#EF553B"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10-14.9%"], "xaxis": "x", "y": [150.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=Nonprofit<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Nonprofit", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "showlegend": false, "type": "box", "x": ["10-14.9%"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Private Sector Financing<br>Returns Profile (Target IRR)=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Private Sector Financing", "marker": {"color": "#00cc96"}, "name": "Private Sector Financing", "offsetgroup": "Private Sector Financing", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10-20%", "10-20%"], "xaxis": "x", "y": [1000.0, 1000.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=Private Sector Financing<br>Returns Profile (Target IRR)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Private Sector Financing", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96", "symbol": "line-ns-open"}, "name": "Private Sector Financing", "offsetgroup": "Privat ...

# %%
fig = px.pie(data, values='AUM', names='Returns Profile (Target IRR)', title='Returns Profile (Target IRR) vs AUM')
fig.show()
# Out:
# <div>                            <div id="d6f0a449-c3a5-4a92-9ee3-623d547a0f5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d6f0a449-c3a5-4a92-9ee3-623d547a0f5d")) {                    Plotly.newPlot(                        "d6f0a449-c3a5-4a92-9ee3-623d547a0f5d",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Returns Profile (Target IRR)=%{label}<br>AUM=%{value}<extra></extra>", "labels": ["5-9.9%", "5-9.9%", "5-9.9%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "22%", "10-14.9%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "7-18%", "10-20%", "10-20%", ">10%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9.80%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "9-10%", "18-22%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "5-9.9%, 10-14.9%", "8%", "8%", "12%", "12%", "12%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "<15%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5.90%", "5-9%", ">10%", ">10%", "10-14.9%", "10-14.9%", "10-14.9%", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1", "USD 35 per USD 1"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0 ...

# %%
fig = px.density_heatmap(data, x="Natural Asset Class", y="AUM", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="87c73a2f-7d50-4883-adf8-445ced4907b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87c73a2f-7d50-4883-adf8-445ced4907b3")) {                    Plotly.newPlot(                        "87c73a2f-7d50-4883-adf8-445ced4907b3",                        [{"coloraxis": "coloraxis", "hovertemplate": "Natural Asset Class=%{x}<br>AUM=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["Wetlands", "Wetlands", "Wetlands", "Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest", "Forest (Riparian) ", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest", "Agroforestry", "Agroforestry", "Wetlands", "Forest (Riparian) ", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest", "Forest (Riparian) ", "Forest", "Forest", "Wetlands", "Forest ", "Wetlands", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest"], "xaxis": "x", "xbingroup": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Natural Asset Class=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["Wetlands", "Wetlands", "Wetlands", "Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest", "Forest (Riparian) ", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest", "Agroforestry", "Agroforestry", "Wetlands", "Forest (Riparian) ", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Wetlands", "Forest", "Forest (Riparian) ", "Forest", "Forest", "Wetlands", "Forest ", "Wetlands", "Forest", "Forest", "Forest", "Forest", "Forest", "Forest" ...

# %%
fig = px.histogram(data, x="Natural Asset Class", y="AUM", marginal="rug",color ="Organization")
fig.show()
# Out:
# <div>                            <div id="8c6987f4-215d-40ac-a6ed-d020bbf3b281" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c6987f4-215d-40ac-a6ed-d020bbf3b281")) {                    Plotly.newPlot(                        "8c6987f4-215d-40ac-a6ed-d020bbf3b281",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=Ecosystem Investment Partners (EIP)<br>Natural Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Ecosystem Investment Partners (EIP)", "marker": {"color": "#636efa"}, "name": "Ecosystem Investment Partners (EIP)", "offsetgroup": "Ecosystem Investment Partners (EIP)", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Wetlands", "Wetlands", "Wetlands"], "xaxis": "x", "y": [885.0, 885.0, 885.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=Ecosystem Investment Partners (EIP)<br>Natural Asset Class=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Ecosystem Investment Partners (EIP)", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "Ecosystem Investment Partners (EIP)", "offsetgroup": "Ecosystem Investment Partners (EIP)", "showlegend": false, "type": "box", "x": ["Wetlands", "Wetlands", "Wetlands"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=Lyme Forest Fund<br>Natural Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Lyme Forest Fund", "marker": {"color": "#EF553B"}, "name": "Lyme Forest Fund", "offsetgroup": "Lyme Forest Fund", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands"], "xaxis": "x", "y": [300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=Lyme Forest Fund<br>Natural Asset Class=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Lyme Forest Fund", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Lyme Forest Fund", "offsetgroup": "Lyme Forest Fund", "showlegend": false, "type": "box", "x": ["Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=The Conservation Fund<br>Natural Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "The Conservation Fund", "marker": {"color": "#00cc96"}, "name": "The Conservation Fund", "offsetgroup": "The Conservation Fund", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Forest"], "xaxis": "x", "y": [150.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=The Conservation Fund<br>Natural Asset Class=%{x}<extra></extra>", "jitter": 0, "legendgroup": "The Conservation Fund", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96", "symbol": "line-ns-open"}, "name": "The Conservation Fund", "offsetgroup": "The Conservation Fund", "showlegend": false, "type": "box", "x": ["Forest"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=New Forests<br>Natural Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "New Forests", "marker": {"color": "#ab6 ...

# %%
fig = px.histogram(data, x="Natural Asset Class", y="AUM", marginal="rug",color ="Type of Organization")
fig.show()
# Out:
# <div>                            <div id="8f1e1f7b-5342-4566-9174-9a7cf8492468" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f1e1f7b-5342-4566-9174-9a7cf8492468")) {                    Plotly.newPlot(                        "8f1e1f7b-5342-4566-9174-9a7cf8492468",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=TIMO<br>Natural Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "TIMO", "marker": {"color": "#636efa"}, "name": "TIMO", "offsetgroup": "TIMO", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Wetlands", "Wetlands", "Wetlands", "Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest", "Forest (Riparian) ", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest"], "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=TIMO<br>Natural Asset Class=%{x}<extra></extra>", "jitter": 0, "legendgroup": "TIMO", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "TIMO", "offsetgroup": "TIMO", "showlegend": false, "type": "box", "x": ["Wetlands", "Wetlands", "Wetlands", "Forest", "Forest", "Forest ", "Wetlands", "Forest", "Forest ", "Wetlands", "Forest", "Wetlands", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest (Riparian) ", "Forest", "Forest (Riparian) ", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest (Tropical)", "Forest (Tropical)", "Forest", "Forest"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Nonprofit<br>Natural Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Nonprofit", "marker": {"color": "#EF553B"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Forest"], "xaxis": "x", "y": [150.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=Nonprofit<br>Natural Asset Class=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Nonprofit", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "showlegend": false, "type": "box", "x": ["Forest"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Private Sector Financing<br>Natural Asset Class=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Private Sector Financing", "marker": {"color": "#00cc96"}, "name": "Private Sector Financing", "offsetgroup": "Private Sector Financing", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Forest (Tropical)", "Forest (Tropical)"], "xaxis": "x", "y": [1000.0, 1000.0], "yaxis": "y"}, {"alignmentgroup":  ...

# %%
fig = px.histogram(data, x="Project Size (hectares)", y="AUM", marginal="rug",color ="Type of Organization")
fig.show()
# Out:
# <div>                            <div id="cb7ae73e-f434-4bd2-ab2a-107a21a24bd2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb7ae73e-f434-4bd2-ab2a-107a21a24bd2")) {                    Plotly.newPlot(                        "cb7ae73e-f434-4bd2-ab2a-107a21a24bd2",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=TIMO<br>Project Size (hectares)=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "TIMO", "marker": {"color": "#636efa"}, "name": "TIMO", "offsetgroup": "TIMO", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500"], "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=TIMO<br>Project Size (hectares)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "TIMO", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "TIMO", "offsetgroup": "TIMO", "showlegend": false, "type": "box", "x": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "36,372", "12,594", "36,372", "12,594", "24,172", "24,172", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Nonprofit<br>Project Size (hectares)=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Nonprofit", "marker": {"color": "#EF553B"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["29947"], "xaxis": "x", "y": [150.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=Nonprofit<br>Project Size (hectares)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Nonprofit", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "showlegend": false, "type": "box", "x": ["29947"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Private Sector Financing<br>Project Size (hectares)=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Private Sector Financing", "marker": {"color": "#00cc96"}, "name": "Private Sector Financing", "offsetgroup": "Private Sector Financing", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["70,000", "18,000"], "xaxis": "x", "y": [1000.0, 1000.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=Private Sector Financing<br>Project Size (hectares)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Private Sector Financing", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96", "symbol": "line ...

# %%
fig = px.histogram(data, x="Project Size (hectares)", y="AUM", marginal="rug",color ="HQ")
fig.show()
# Out:
# <div>                            <div id="034700c8-d0d2-4263-a957-e39242dcc81c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("034700c8-d0d2-4263-a957-e39242dcc81c")) {                    Plotly.newPlot(                        "034700c8-d0d2-4263-a957-e39242dcc81c",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=USA<br>Project Size (hectares)=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "USA", "marker": {"color": "#636efa"}, "name": "USA", "offsetgroup": "USA", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386"], "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "HQ=USA<br>Project Size (hectares)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "USA", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "USA", "offsetgroup": "USA", "showlegend": false, "type": "box", "x": ["10,000", "405", "4,046 per year", "273,972", "112,502", "38,594", "38,594", "64,749", "45,325", "45,325", "36,219", "29", "29947", "170,500", "68,000", "106,000", "25,500", "19,000", "9,000", "266,500", "33,500", "1,336", "640", "640", "350", "2062", "1961", "761", "761", "1,031", "761", "2,596", "5,377", "5,377", "10,392", "16,000", "102,386"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=Australia<br>Project Size (hectares)=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Australia", "marker": {"color": "#EF553B"}, "name": "Australia", "offsetgroup": "Australia", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000"], "xaxis": "x", "y": [2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "HQ=Australia<br>Project Size (hectares)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Australia", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Australia", "offsetgroup": "Australia", "showlegend": false, "type": "box", "x": ["10,000", "10,000", "10,000", "10,000", "10,000", "10,000", "10,000"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=Indonesia<br>Project Size (hectares)=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Indonesia", "marker": {"color": "#00cc96"}, "name": "Indonesia", "offsetgroup": "Indonesia", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["70,000", "18,000"], "xaxis": "x", "y": [1000.0, 1000.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "HQ=Indonesia<br>Project Size (hectares)=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Indonesia", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96", "sy ...

# %%
fig = px.density_heatmap(data, x="Project State", y="AUM", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="2cc0c0b5-cdc1-4a84-87a4-58e9f3343aad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2cc0c0b5-cdc1-4a84-87a4-58e9f3343aad")) {                    Plotly.newPlot(                        "2cc0c0b5-cdc1-4a84-87a4-58e9f3343aad",                        [{"coloraxis": "coloraxis", "hovertemplate": "Project State=%{x}<br>AUM=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["CA", "CA", "CA", "MI, WI", "NY", "FL", "FL", "PA, NY", "CA", "CA", "TN", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "Jambi", "East Kalimantan", "East Kalimantan", "Minas Gerais", "Parana ", "Minas Gerais", "Parana ", "Antioquia & Caldas", "Medellin", "Curitiba", "Montevideo", "Santiago ", null, "Guatemala City", null, null, "Auckland", null, "Cotopaxi", "Upala", "Ahuachapan Province", "South Sumatra", "Izabal", "Yoni", "Ashanti Region", "San Estanisalo", "Limpopo", "Western Cape, Eastern Cape, Mpumalanga", "Eastern Cape", "Mpumalanga", "Morogoro", "Piggs Peak", "Sabie", "Mpumalanga", null, "WA", "WA", "WA", "WA", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "CA", "VA, KY, TN", null, null, null, null, null, null, null, null, null, null, null, null, null], "xaxis": "x", "xbingroup": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Project State=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["CA", "CA", "CA", "MI, WI", "NY", "FL", "FL", "PA, NY", "CA", "CA", "TN", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "Jambi", "East Kalimantan", "East Kalimantan", "Minas Gerais", "Parana ", "Minas Gerais", "Parana ", "Antioquia & Caldas", "Medellin", "Curitiba", "Montevideo", "Santiago ", null, "Guatemala City", null, null, "Auckland", null, "Cotopaxi", "Upala", "Ahuachapan Province", "South Sumatra", "Izabal", "Yoni", "Ashanti Region", "San Estanisalo", "Limpopo", "Western Cape, Eastern Cape, Mpumalanga", "Eastern Cape", "Mpumalanga", "Morogoro", "Piggs Peak", "Sabie", "Mpumalanga", null, "WA", "WA", "WA", "WA", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "CA", "VA, KY, TN", null, null, null, null, null, null, null, null, null, null, null, null, null], "xaxis": "x3", "yaxis": "y3"}, {"alignmentgroup": "True", "bingroup": "y", "hovertemplate": "AUM=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "xaxis": "x2", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54. ...

# %%
fig = px.box(data, x='Project State', y='AUM')
fig.show()
# Out:
# <div>                            <div id="165ddb80-a6e4-4c09-af05-8153264fb4ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("165ddb80-a6e4-4c09-af05-8153264fb4ef")) {                    Plotly.newPlot(                        "165ddb80-a6e4-4c09-af05-8153264fb4ef",                        [{"alignmentgroup": "True", "hovertemplate": "Project State=%{x}<br>AUM=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "notched": false, "offsetgroup": "", "orientation": "v", "showlegend": false, "type": "box", "x": ["CA", "CA", "CA", "MI, WI", "NY", "FL", "FL", "PA, NY", "CA", "CA", "TN", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "Jambi", "East Kalimantan", "East Kalimantan", "Minas Gerais", "Parana ", "Minas Gerais", "Parana ", "Antioquia & Caldas", "Medellin", "Curitiba", "Montevideo", "Santiago ", null, "Guatemala City", null, null, "Auckland", null, "Cotopaxi", "Upala", "Ahuachapan Province", "South Sumatra", "Izabal", "Yoni", "Ashanti Region", "San Estanisalo", "Limpopo", "Western Cape, Eastern Cape, Mpumalanga", "Eastern Cape", "Mpumalanga", "Morogoro", "Piggs Peak", "Sabie", "Mpumalanga", null, "WA", "WA", "WA", "WA", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "OR", "CA", "VA, KY, TN", null, null, null, null, null, null, null, null, null, null, null, null, null], "x0": " ", "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0], "y0": " ", "yaxis": "y"}],                        {"boxmode": "group", "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [ ...

# %%
fig = px.histogram(data, x="Project State", y="AUM", marginal="rug",color ="Type of Organization")
fig.show()
# Out:
# <div>                            <div id="26eb930d-f765-42c0-9f86-11ac6945c6ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26eb930d-f765-42c0-9f86-11ac6945c6ee")) {                    Plotly.newPlot(                        "26eb930d-f765-42c0-9f86-11ac6945c6ee",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=TIMO<br>Project State=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "TIMO", "marker": {"color": "#636efa"}, "name": "TIMO", "offsetgroup": "TIMO", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["CA", "CA", "CA", "MI, WI", "NY", "FL", "FL", "PA, NY", "CA", "CA", "TN", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "Minas Gerais", "Parana ", "Minas Gerais", "Parana ", "Antioquia & Caldas", "Medellin", "Curitiba", "Montevideo", "Santiago ", null, "Guatemala City", null, null, "Auckland"], "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=TIMO<br>Project State=%{x}<extra></extra>", "jitter": 0, "legendgroup": "TIMO", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "TIMO", "offsetgroup": "TIMO", "showlegend": false, "type": "box", "x": ["CA", "CA", "CA", "MI, WI", "NY", "FL", "FL", "PA, NY", "CA", "CA", "TN", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "CA", "Minas Gerais", "Parana ", "Minas Gerais", "Parana ", "Antioquia & Caldas", "Medellin", "Curitiba", "Montevideo", "Santiago ", null, "Guatemala City", null, null, "Auckland"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Nonprofit<br>Project State=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Nonprofit", "marker": {"color": "#EF553B"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["CA"], "xaxis": "x", "y": [150.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=Nonprofit<br>Project State=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Nonprofit", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Nonprofit", "offsetgroup": "Nonprofit", "showlegend": false, "type": "box", "x": ["CA"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Type of Organization=Private Sector Financing<br>Project State=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Private Sector Financing", "marker": {"color": "#00cc96"}, "name": "Private Sector Financing", "offsetgroup": "Private Sector Financing", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Jambi", "East Kalimantan"], "xaxis": "x", "y": [1000.0, 1000.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Type of Organization=Private Sector Financing<br>Project State=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Private Sector Financing", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96", "symbol": "line-ns-open"}, "name": "Private Sector Financing", "offsetgroup": "Private Sector Financing", "showlegend": false, "type": "box", "x": [" ...

# %%
fig = px.pie(data, values='AUM', names='Project Country', title='Project Country vs AUM')
fig.show()
# Out:
# <div>                            <div id="7c8cecc5-4ee6-43f1-abdf-7a4aec76d0b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c8cecc5-4ee6-43f1-abdf-7a4aec76d0b6")) {                    Plotly.newPlot(                        "7c8cecc5-4ee6-43f1-abdf-7a4aec76d0b6",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "Project Country=%{label}<br>AUM=%{value}<extra></extra>", "labels": ["USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Indonesia", "Indonesia", "Indonesia", "Brazil", "Brazil", "Brazil", "Brazil", "Colombia", "Colombia", "Brazil", "Uruguay", "Chile", "Colombia", "Guatemala", "Cambodia", "Australia", "New Zealand", "Paraguay", "Ecuador", "Costa Rica", "El Salvador", "Indonesia", "Guatemala", "Sierra Leone", "Ghana", "Paraguay", "South Africa", "South Africa", "South Africa", "South Africa", "Tanzania", "Swaziland", "South Africa", "South Africa", "Gabon", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Guatemala", "Guatemala", "Pan-African", "Pan-African", "Portugal", "Ethiopia", "Nigeria", "Senegal", "Tanzania", "Rwanda", "Niger", "Mozambique", "Malawi"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0]}],                        {"legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.444444444444 ...

# %%
fig = px.density_heatmap(data, x="Project Country", y="AUM", marginal_x="histogram", marginal_y="histogram")
fig.show()
# Out:
# <div>                            <div id="15c96a93-8b53-4649-89b8-da94def5794f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15c96a93-8b53-4649-89b8-da94def5794f")) {                    Plotly.newPlot(                        "15c96a93-8b53-4649-89b8-da94def5794f",                        [{"coloraxis": "coloraxis", "hovertemplate": "Project Country=%{x}<br>AUM=%{y}<br>count=%{z}<extra></extra>", "name": "", "type": "histogram2d", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Indonesia", "Indonesia", "Indonesia", "Brazil", "Brazil", "Brazil", "Brazil", "Colombia", "Colombia", "Brazil", "Uruguay", "Chile", "Colombia", "Guatemala", "Cambodia", "Australia", "New Zealand", "Paraguay", "Ecuador", "Costa Rica", "El Salvador", "Indonesia", "Guatemala", "Sierra Leone", "Ghana", "Paraguay", "South Africa", "South Africa", "South Africa", "South Africa", "Tanzania", "Swaziland", "South Africa", "South Africa", "Gabon", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Guatemala", "Guatemala", "Pan-African", "Pan-African", "Portugal", "Ethiopia", "Nigeria", "Senegal", "Tanzania", "Rwanda", "Niger", "Mozambique", "Malawi"], "xaxis": "x", "xbingroup": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0, 54.0, 54.0, 75.0, 75.0, 75.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0, 481.0], "yaxis": "y", "ybingroup": "y"}, {"alignmentgroup": "True", "bingroup": "x", "hovertemplate": "Project Country=%{x}<br>count=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Indonesia", "Indonesia", "Indonesia", "Brazil", "Brazil", "Brazil", "Brazil", "Colombia", "Colombia", "Brazil", "Uruguay", "Chile", "Colombia", "Guatemala", "Cambodia", "Australia", "New Zealand", "Paraguay", "Ecuador", "Costa Rica", "El Salvador", "Indonesia", "Guatemala", "Sierra Leone", "Ghana", "Paraguay", "South Africa", "South Africa", "South Africa", "South Africa", "Tanzania", "Swaziland", "South Africa", "South Africa", "Gabon", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Guatemala", "Guatemala", "Pan-African", "Pan-African", "Portugal", "Ethiopia", "Nigeria", "Senegal", "Tanzania", "Rwanda", "Niger", "Mozambique", "Malawi"], "xaxis": "x3", "yaxis": "y3"}, {"alignmentgroup": "True", "bingroup": "y", "hovertemplate": "AUM=%{y}<br>count=%{x}<extra></extra>", "legendgroup": "", "marker": {"color": "#0d0887"}, "name": "", "offsetgroup": "", "opacity": 0.5, "showlegend": false, "type": "histogram", "xaxis": "x2", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 1000.0, 1000.0, 60.0, 381.0, 381.0, 381.0, 381.0, 381.0, 381.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 10000.0, 429.5, 429.5, 429.5, 380.0, 380.0, 60.2, 60.2, 60.2, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242.0, 242 ...

# %%
fig = px.histogram(data, x="Project Country", y="AUM", marginal="rug",color ="Organization")
fig.show()
# Out:
# <div>                            <div id="613660e7-376d-4fff-b7d5-ab9d38274d9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("613660e7-376d-4fff-b7d5-ab9d38274d9a")) {                    Plotly.newPlot(                        "613660e7-376d-4fff-b7d5-ab9d38274d9a",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=Ecosystem Investment Partners (EIP)<br>Project Country=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Ecosystem Investment Partners (EIP)", "marker": {"color": "#636efa"}, "name": "Ecosystem Investment Partners (EIP)", "offsetgroup": "Ecosystem Investment Partners (EIP)", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["USA", "USA", "USA"], "xaxis": "x", "y": [885.0, 885.0, 885.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=Ecosystem Investment Partners (EIP)<br>Project Country=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Ecosystem Investment Partners (EIP)", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "Ecosystem Investment Partners (EIP)", "offsetgroup": "Ecosystem Investment Partners (EIP)", "showlegend": false, "type": "box", "x": ["USA", "USA", "USA"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=Lyme Forest Fund<br>Project Country=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Lyme Forest Fund", "marker": {"color": "#EF553B"}, "name": "Lyme Forest Fund", "offsetgroup": "Lyme Forest Fund", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA"], "xaxis": "x", "y": [300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=Lyme Forest Fund<br>Project Country=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Lyme Forest Fund", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Lyme Forest Fund", "offsetgroup": "Lyme Forest Fund", "showlegend": false, "type": "box", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=The Conservation Fund<br>Project Country=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "The Conservation Fund", "marker": {"color": "#00cc96"}, "name": "The Conservation Fund", "offsetgroup": "The Conservation Fund", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["USA"], "xaxis": "x", "y": [150.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "Organization=The Conservation Fund<br>Project Country=%{x}<extra></extra>", "jitter": 0, "legendgroup": "The Conservation Fund", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96", "symbol": "line-ns-open"}, "name": "The Conservation Fund", "offsetgroup": "The Conservation Fund", "showlegend": false, "type": "box", "x": ["USA"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "Organization=New Forests<br>Project Country=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "New Forests", "marker": {"color": "#ab63fa"}, "name": "New Forests", "offsetgroup": "New Forests", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["USA",  ...

# %%
fig = px.histogram(data, x="Project Country", y="AUM", marginal="rug",color ="HQ")
fig.show()
# Out:
# <div>                            <div id="b0b3af25-ee4c-441d-8a6f-f8c3d9770788" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b0b3af25-ee4c-441d-8a6f-f8c3d9770788")) {                    Plotly.newPlot(                        "b0b3af25-ee4c-441d-8a6f-f8c3d9770788",                        [{"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=USA<br>Project Country=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "USA", "marker": {"color": "#636efa"}, "name": "USA", "offsetgroup": "USA", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Brazil", "Uruguay", "Chile", "Colombia", "Guatemala", "Cambodia", "Australia", "New Zealand", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA"], "xaxis": "x", "y": [885.0, 885.0, 885.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 300.0, 150.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 3000.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 190.0, 130.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "HQ=USA<br>Project Country=%{x}<extra></extra>", "jitter": 0, "legendgroup": "USA", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#636efa", "symbol": "line-ns-open"}, "name": "USA", "offsetgroup": "USA", "showlegend": false, "type": "box", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "Brazil", "Uruguay", "Chile", "Colombia", "Guatemala", "Cambodia", "Australia", "New Zealand", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA", "USA"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=Australia<br>Project Country=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Australia", "marker": {"color": "#EF553B"}, "name": "Australia", "offsetgroup": "Australia", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA"], "xaxis": "x", "y": [2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0, 2800.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "HQ=Australia<br>Project Country=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Australia", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#EF553B", "symbol": "line-ns-open"}, "name": "Australia", "offsetgroup": "Australia", "showlegend": false, "type": "box", "x": ["USA", "USA", "USA", "USA", "USA", "USA", "USA"], "xaxis": "x2", "yaxis": "y2"}, {"alignmentgroup": "True", "bingroup": "x", "histfunc": "sum", "hovertemplate": "HQ=Indonesia<br>Project Country=%{x}<br>sum of AUM=%{y}<extra></extra>", "legendgroup": "Indonesia", "marker": {"color": "#00cc96"}, "name": "Indonesia", "offsetgroup": "Indonesia", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Indonesia", "Indonesia"], "xaxis": "x", "y": [1000.0, 1000.0], "yaxis": "y"}, {"alignmentgroup": "True", "boxpoints": "all", "fillcolor": "rgba(255,255,255,0)", "hoveron": "points", "hovertemplate": "HQ=Indonesia<br>Project Country=%{x}<extra></extra>", "jitter": 0, "legendgroup": "Indonesia", "line": {"color": "rgba(255,255,255,0)"}, "marker": {"color": "#00cc96", "symbol": "line-ns-open"}, "name": "Indonesia", "offsetgroup": "Indonesia", "showlegend": false, "type": "box", "x": ["Indonesia", "Indonesia"], "xaxis": "x2", "yaxis": "y2"}, {"alignment ...
